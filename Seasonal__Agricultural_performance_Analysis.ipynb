# %% [markdown]
# # **Seasonal Agricultural Performance Analysis**

# %% [markdown]
# Data Analysis By Syeda Tahoora Fatima

# %% [markdown]
# ## 1. **Introduction**
#
# Agricultural performance is influenced by several factors such as seasonal
# conditions, rainfall, temperature, soil characteristics, farming practices,
# resource availability and economic conditions.
#
# This project analyzes agricultural data collected across different seasons,
# regions, crops and farming conditions. The primary focus is to understand how
# agricultural performance changes across Kharif, Rabi and Zaid seasons.
#
# The analysis examines seasonal variations in yield, production, resource
# usage, environmental conditions, water efficiency, economic performance and
# disease/pest risk.
#
# The project uses data analytics, statistical analysis and visualization
# techniques to identify meaningful seasonal patterns and provide
# evidence-based conclusions and recommendations.

# %% [markdown]
# ## 2. **Problem Statement**
#
# Agricultural activities are affected by seasonal variations in environmental
# conditions, farming practices, resource availability and market conditions.
# Therefore, agricultural performance may differ considerably across seasons.
#
# However, raw agricultural data does not directly reveal how agricultural
# performance changes between seasons or which environmental, resource and
# economic factors are associated with these differences.
#
# The purpose of this project is to analyze the agricultural dataset and
# investigate seasonal differences in agricultural performance by identifying
# patterns, relationships, variations and unusual observations across seasons,
# regions, crops and farming conditions.

# %% [markdown]
# ## 3. **Objectives**
#
# The main objectives of this project are:
#
# 1. TExplore and understand the dataset.
# 2. Clean and prepare the data for analysis.
# 3. Examine how agricultural performance varies across seasons.
# 4. Identify important seasonal patterns and trends.
# 5. Investigate relationships between seasonal conditions and agricultural outcomes.
# 6. Compare relevant groups within different seasons.
# 7. Identify significant differences or unusual patterns.
# 8. Apply appropriate statistical and visualization techniques.
# 9. Interpret findings based on evidence from the dataset.
# 10. Develop meaningful conclusions and data-driven recommendations.

# %% [markdown]
# ## 4. **Research Questions**
#
# RQ1. How does agricultural yield vary across Kharif, Rabi and Zaid seasons?
#
# RQ2. What major seasonal patterns can be observed?
#
# RQ3. Which characteristics change between seasons?
#
# RQ4. What differences exist between agricultural activities in different seasons?
#
# RQ5. Are there noticeable variations in resource usage across seasons?
#
# RQ6. Are there relationships between seasonal environmental conditions and
# agricultural performance?
#
# RQ7. How do economic outcomes vary across seasons?
#
# RQ8. Are some seasonal patterns consistent across different regions or categories?
#
# RQ9. Are there unusual or unexpected seasonal patterns?
#
# RQ10. What insights can be derived from the observed seasonal differences?
#
# RQ11. What conclusions can reasonably be drawn from the available data?
#
# RQ12. How could the findings support better seasonal agricultural planning?

# %% [markdown]
# ## 5. **Import Libraries**

# %%
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical analysis
from scipy import stats

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 6. **LOAD DATASET**

# %%
df = pd.read_csv("/content/seasonal_agriculture_performance_dataset.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %% [markdown]
# ## **7. Dataset Overview**

# %%
# Display first 5 rows
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
# Display last 5 rows
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 3995        865.4               27.3          51.4                 6.3  ...
# 3996        947.5               29.2          85.5                 6.1  ...
# 3997         80.0               35.4          68.5                 8.6  ...
# 3998        475.0               28.2          61.7                 6.4  ...
# 3999        984.3               25.8          77.2                 5.9  ...
#
# ...

# %% [markdown]
# ## 8. **Dataset Understanding**

# %%
# Dataset Dimensions
# Check number of rows and columns

rows, columns = df.shape

print("Number of Rows:", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows: 4000
# Number of Columns: 28

# %% [markdown]
# ### Important Columns for Analysis
#
# Based on the problem statement and the objectives, the following columns are particularly important for understanding seasonal agricultural performance:
#
# *   **Seasonal and Regional Identifiers:**
#     *   `Season`: Directly addresses seasonal variations.
#     *   `State`, `District`: Provides regional context for analysis.
#     *   `Crop`: Allows for crop-specific seasonal analysis.
#     *   `Farm_ID`: Unique identifier for individual farms (useful for grouping or distinct counts).
#
# *   **Environmental Factors:**
#     *   `Rainfall_mm`: Crucial for understanding water availability and seasonal climate.
#     *   `Avg_Temperature_C`: Key climatic factor varying by season.
#     *   `Humidity_pct`: Environmental condition influencing crop health.
#     *   `Sunlight_Hours_Day`: Directly impacts photosynthesis and growth.
#     *   `Soil_pH`, `Soil_Moisture_pct`: Important soil characteristics.
#     *   `Disease_Pest_Risk_pct`: Indicates environmental impact on crop health.
#
# *   **Resource Usage and Farming Practices:**
#     *   `Farm_Area_Hectares`: Farm size can influence overall production.
#     *   `Nitrogen_kg_ha`, `Phosphorus_kg_ha`, `Potassium_kg_ha`: Nutrient application related to farming practices.
#     *   `Irrigation_Method`: Shows different water management strategies.
#     *   `Fertilizer_kg_ha`, `Pesticide_Litre_ha`: Input usage in farming.
#     *   `Seed_Quality_Score`: Reflects the quality of planting material.
#     *   `Water_Used_m3`, `Water_Efficiency_t_per_1000m3`: Direct measures of water resource management.
#
# *   **Agricultural Outcomes/Performance:**
#     *   `Yield_Tonnes_Ha`: The primary measure of agricultural output.
#     *   `Production_Tonnes`: Overall production volume.
#     *   `Market_Price_INR_Tonne`, `Total_Cost_INR`, `Revenue_INR`, `Profit_INR`: Key economic indicators of performance.

# %%
# Display all column names

for i, column in enumerate(df.columns, start=1):
    print(i, ":", column)
# Out:
# 1 : Farm_ID
# 2 : State
# 3 : District
# 4 : Crop
# 5 : Season
# 6 : Farm_Area_Hectares
# 7 : Rainfall_mm
# 8 : Avg_Temperature_C
# 9 : Humidity_pct
# 10 : Sunlight_Hours_Day
# 11 : Soil_pH
# 12 : Soil_Moisture_pct
# 13 : Nitrogen_kg_ha
# 14 : Phosphorus_kg_ha
# 15 : Potassium_kg_ha
# 16 : Irrigation_Method
# 17 : Fertilizer_kg_ha
# 18 : Pesticide_Litre_ha
# 19 : Seed_Quality_Score
# 20 : Yield_Tonnes_Ha
# 21 : Production_Tonnes
# 22 : Market_Price_INR_Tonne
# 23 : Total_Cost_INR
# 24 : Revenue_INR
# 25 : Profit_INR
# 26 : Water_Used_m3
# 27 : Water_Efficiency_t_per_1000m3
# 28 : Disease_Pest_Risk_pct

# %%
# Display dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
# Generate descriptive statistics for numerical columns

df.describe().T
# Out:
#                                 count           mean            std  \
# Farm_Area_Hectares             4000.0       7.888265       4.223764
# Rainfall_mm                    3952.0     601.152657     288.925025
# Avg_Temperature_C              4000.0      26.818900       3.818180
# Humidity_pct                   4000.0      63.210500      11.960834
# Sunlight_Hours_Day             4000.0       7.323050       1.121186
# Soil_pH                        4000.0       6.701010       0.641461
# Soil_Moisture_pct              3960.0      26.508232       6.712484
# Nitrogen_kg_ha                 4000.0     120.250825      31.216452
# Phosphorus_kg_ha               4000.0      57.781850      17.015074
# Potassium_kg_ha                4000.0     104.760050      27.742681
# Fertilizer_kg_ha               4000.0     186.036000      60.260583
# Pesticide_Litre_ha             4000.0       5.070935       1.978879
# Seed_Quality_Score             4000.0       0.826138       0.101747
# ...

# %%
# Categorical Variables
# Display unique values for important categorical columns

categorical_columns = [
    'State',
    'District',
    'Crop',
    'Season',
    'Irrigation_Method'
]

for column in categorical_columns:
    print("\n" + "="*50)
    print(column)
    print("="*50)
    print(df[column].unique())
# Out:
# ...
# State
# ...
# ['Andhra Pradesh' 'Maharashtra' 'Telangana' 'Karnataka' 'Gujarat'
#  'Tamil Nadu' 'Punjab' 'Madhya Pradesh']
#
# ...
# District
# ...
# ['Rajkot' 'Nalgonda' 'Warangal' 'Indore' 'Ludhiana' 'Raichur' 'Guntur'
#  'Krishna' 'Nashik' 'Erode']
#
# ...
# Crop
# ...
# ['Wheat' 'Maize' 'Pulses' 'Rice' 'Cotton' 'Chilli' 'Groundnut' 'Sugarcane']
#
# ...
# Season
# ...
# ['Kharif' 'Rabi' 'Zaid']
#
# ...
# Irrigation_Method
# ...
# ['Drip' 'Flood' 'Rainfed' 'Sprinkler']

# %%
## Frequency of Categories
# Count observations in each season

print("Season Distribution:")
print(df['Season'].value_counts())
# Out:
# Season Distribution:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
# Count crops

print("Crop Distribution:")
print(df['Crop'].value_counts())
# Out:
# Crop Distribution:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %%
# Count irrigation methods

print("Irrigation Method Distribution:")
print(df['Irrigation_Method'].value_counts())
# Out:
# Irrigation Method Distribution:
# Irrigation_Method
# Flood        1310
# Rainfed      1041
# Drip          915
# Sprinkler     734
# Name: count, dtype: int64

# %%
# Count State
print("State Distribution:")
print(df['State'].value_counts())
# Out:
# State Distribution:
# State
# Andhra Pradesh    529
# Telangana         516
# Maharashtra       512
# Madhya Pradesh    497
# Karnataka         489
# Gujarat           488
# Tamil Nadu        485
# Punjab            484
# Name: count, dtype: int64

# %%
# Count Districts
print("District Distribution:")
print(df['District'].value_counts())
# Out:
# District Distribution:
# District
# Ludhiana    427
# Warangal    422
# Nalgonda    415
# Erode       403
# Rajkot      401
# Krishna     393
# Indore      392
# Guntur      390
# Raichur     386
# Nashik      371
# Name: count, dtype: int64

# %% [markdown]
# ## 9. **Data Cleaning**

# %% [markdown]
# ### Checking Missing Values

# %%
# Check missing values in every column

missing_values = df.isnull().sum()

missing_table = pd.DataFrame({
    'Missing Values': missing_values,
    'Missing Percentage': (missing_values / len(df)) * 100
})

missing_table = missing_table.sort_values(
    by='Missing Values',
    ascending=False
)

missing_table
# Out:
#                                Missing Values  Missing Percentage
# Rainfall_mm                                48                 1.2
# Soil_Moisture_pct                          40                 1.0
# Yield_Tonnes_Ha                            32                 0.8
# Farm_ID                                     0                 0.0
# Crop                                        0                 0.0
# District                                    0                 0.0
# Farm_Area_Hectares                          0                 0.0
# Season                                      0                 0.0
# Avg_Temperature_C                           0                 0.0
# Humidity_pct                                0                 0.0
# Sunlight_Hours_Day                          0                 0.0
# State                                       0                 0.0
# Soil_pH                                     0                 0.0
# ...

# %% [markdown]
# ### Visualizing Missing Values

# %%
# Select columns containing missing values

missing = df.isnull().sum()
missing = missing[missing > 0]

plt.figure(figsize=(10, 5))

missing.plot(kind='bar')

plt.title("Missing Values by Column")
plt.xlabel("Column")
plt.ylabel("Number of Missing Values")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Handling Missing Values

# %%
# Environmental variables
df['Rainfall_mm'] = df['Rainfall_mm'].fillna(
    df['Rainfall_mm'].median()
)

df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(
    df['Soil_Moisture_pct'].median()
)

print("Rainfall and Soil Moisture missing values handled.")
# Out:
# Rainfall and Soil Moisture missing values handled.

# %%
# Handling missing value for the column Yield_Tonnes_Ha
yield_df = df.dropna(subset=['Yield_Tonnes_Ha']).copy()

print("Original dataset size:", df.shape)
print("Yield analysis dataset size:", yield_df.shape)
# Out:
# Original dataset size: (4000, 28)
# Yield analysis dataset size: (3968, 28)

# %% [markdown]
# ### Verifying missing values

# %%
# Check remaining missing values

remaining_missing = df.isnull().sum()

remaining_missing = remaining_missing[
    remaining_missing > 0
]

remaining_missing
# Out:
# Yield_Tonnes_Ha    32
# dtype: int64

# %% [markdown]
# ## Duplicate Checking
# ### Check Duplicate Records

# %%
# Count duplicate rows

duplicate_count = df.duplicated().sum()

print("Number of duplicate records:", duplicate_count)
# Out:
# Number of duplicate records: 0

# %%
# Check whether Farm_ID values are duplicated

duplicate_farm_ids = df['Farm_ID'].duplicated().sum()

print("Duplicate Farm IDs:", duplicate_farm_ids)
# Out:
# Duplicate Farm IDs: 0

# %% [markdown]
# ### Checking Data Types

# %%
# Display data types

df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %% [markdown]
# ## Check Invalid Values

# %%
# Check negative values in numerical columns

numeric_columns = df.select_dtypes(include=np.number).columns

negative_values = {}

for column in numeric_columns:
    count = (df[column] < 0).sum()
    if count > 0:
        negative_values[column] = count

negative_values
# Out:
# {'Profit_INR': np.int64(1966)}

# %% [markdown]
# #### Investigating 'Profit_INR' column

# %%
df['Profit_INR'].describe()
# Out:
# count    4.000000e+03
# mean     1.115565e+05
# std      5.450819e+05
# min     -1.019223e+06
# 25%     -1.487318e+05
# 50%      3.673000e+03
# 75%      2.161878e+05
# max      4.345421e+06
# Name: Profit_INR, dtype: float64

# %%
df[df['Profit_INR'] < 0]['Profit_INR'].head(5)
# Out:
# 0    -11852
# 1   -451950
# 2   -124744
# 3    -95704
# 4   -144352
# Name: Profit_INR, dtype: int64

# %%
print("Negative Profit:", (df['Profit_INR'] < 0).sum())
print("Zero Profit:", (df['Profit_INR'] == 0).sum())
print("Positive Profit:", (df['Profit_INR'] > 0).sum())
# Out:
# Negative Profit: 1966
# Zero Profit: 0
# Positive Profit: 2034

# %%
total = len(df)

negative_pct = (df['Profit_INR'] < 0).sum() / total * 100
positive_pct = (df['Profit_INR'] > 0).sum() / total * 100

print(f"Negative Profit: {negative_pct:.2f}%")
print(f"Positive Profit: {positive_pct:.2f}%")
# Out:
# Negative Profit: 49.15%
# Positive Profit: 50.85%

# %%
# Display information about the cleaned dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    4000 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              4000 non-null   float64
# ...

# %% [markdown]
# Profitability Insight: The dataset contains 4,000 observations, of which 1,966 (49.15%) report negative profit and 2,034 (50.85%) report positive profit. This indicates that the dataset contains a nearly equal distribution of profitable and loss-making farming observations. Negative profit values are valid because they represent situations where production costs exceed revenue and therefore should not be removed during data cleaning.

# %%
# Convert categorical variables to category datatype
categorical_columns = [
    'State',
    'District',
    'Crop',
    'Season',
    'Irrigation_Method'
]

for column in categorical_columns:
    df[column] = df[column].astype('category')

print("Categorical columns converted successfully.")
# Out:
# Categorical columns converted successfully.

# %% [markdown]
# ### Checking the cleaned dataset

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %% [markdown]
# ## **10. Outlier Analysis**

# %% [markdown]
# ### Outlier Detection

# %%
# OUTLIER DETECTION USING IQR

def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[
        (data[column] < lower_bound) |
        (data[column] > upper_bound)
    ]

    return len(outliers), lower_bound, upper_bound


important_numeric_columns = [
    'Rainfall_mm',
    'Avg_Temperature_C',
    'Humidity_pct',
    'Soil_Moisture_pct',
    'Fertilizer_kg_ha',
    'Pesticide_Litre_ha',
    'Yield_Tonnes_Ha',
    'Production_Tonnes',
    'Profit_INR',
    'Water_Used_m3',
    'Water_Efficiency_t_per_1000m3',
    'Disease_Pest_Risk_pct'
]

outlier_results = []

for column in important_numeric_columns:
    count, lower, upper = detect_outliers_iqr(
        yield_df if column == 'Yield_Tonnes_Ha' else df,
        column
    )

    outlier_results.append([
        column,
        count,
        lower,
        upper
    ])

outlier_table = pd.DataFrame(
    outlier_results,
    columns=[
        'Variable',
        'Outlier_Count',
        'Lower_Bound',
        'Upper_Bound'
    ]
)

outlier_table
# Out:
#                          Variable  Outlier_Count    Lower_Bound    Upper_Bound
# 0                     Rainfall_mm              0    -319.025000    1522.575000
# 1               Avg_Temperature_C              2      15.350000      38.150000
# 2                    Humidity_pct              6      29.087500      97.587500
# 3               Soil_Moisture_pct              5       7.700000      45.300000
# 4                Fertilizer_kg_ha             15      19.137500     352.037500
# 5              Pesticide_Litre_ha              8      -0.375000      10.465000
# 6                 Yield_Tonnes_Ha            302      -1.635000       5.525000
# 7               Production_Tonnes            333     -23.982500      53.357500
# 8                      Profit_INR            404 -696111.000000  763567.000000
# 9                   Water_Used_m3            276   -6072.750000   16171.250000
# 10  Water_Efficiency_t_per_1000m3            322      -3.572875      10.384125
# ...

# %% [markdown]
# ### Outliers Analysis Insights
#
# | Data Category | Number of Outliers | Meaning of Extreme Values |
# | :--- | :--- | :--- |
# | **Financials** (*Profit_INR*) | 404 | Reflects extreme business risks (losing money) or massive success (high market prices). |
# | **Farm Outcomes** (*Yield, Production, Water Efficiency*) | 302 – 333 | Represents major crop successes (best practices) or total crop failures (disease, bad weather). |
# | **Resource Usage** (*Water_Used_m3*) | 276 | Highlights very thirsty crop types, large farms, or severe dry spells. |
# | **Environment & Inputs** (*Weather, Soil, Fertilizers, Pests*) | 2 – 15 | Shows that extreme weather events or heavy chemical use are rare but important to watch. |
# | **Rainfall** (*Rainfall_mm*) | 0 | Shows that while rain amounts changed, there were no statistically crazy weather extremes. |

# %% [markdown]
# ### Outlier Visualizattion Using Box Plots

# %%
import matplotlib.pyplot as plt

for column in important_numeric_columns:

    data = yield_df[column] if column == 'Yield_Tonnes_Ha' else df[column]

    plt.figure(figsize=(8, 4))
    plt.boxplot(data.dropna())
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ### RQ9. Are there unusual or unexpected seasonal patterns?
# Yes.
# 1. Punjab's Rabi performance
# Punjab Rabi yield = 8.61 t/ha
# This is the highest state-season yield in the dataset.
#
# Interpretation:
#
# Rabi is not necessarily a poor season everywhere.
# Regional factors can make Rabi highly successful.
#
# 2. Karnataka's Zaid performance
# Karnataka Zaid = 6.62 t/ha
# Karnataka Kharif = 6.52 t/ha
#
# Interpretation:
#
# Zaid can perform very well in certain regions.
#
# 3. Maharashtra
# Kharif = 5.45
# Rabi = 5.50
#
# Interpretation:
#
# There is almost no difference between these two seasons.
#
# 4. High Sugarcane values
# Sugarcane yield is around 40–53 t/ha, much higher than other crops.
#
# Interpretation:
#
# This explains many of the detected IQR outliers.
# These values should not automatically be treated as errors.
#
# 5. High yield does not always mean high profit
# Maize average yield: 2.72 t/ha, but average profit is −₹82,749
# Rice: 2.44 t/ha, profit −₹101,405
# Wheat: 2.11 t/ha, profit −₹123,568
# Chilli: only 1.54 t/ha, but average profit ₹753,378
#
# Interpretation:
#
# Yield alone is not enough to judge agricultural success.
# Market price and production costs are also important.

# %% [markdown]
# ## **11. Univariate Analysis**

# %% [markdown]
# ### Yield distribution

# %%
plt.figure(figsize=(5, 5))

sns.histplot(
    yield_df['Yield_Tonnes_Ha'],
    bins=30,
    kde=True
)

plt.title("Distribution of Agricultural Yield")
plt.xlabel("Yield (Tonnes per Hectare)")
plt.ylabel("Number of Farms")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Season Distribution

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x='Season',
    order=df['Season'].value_counts().index
)

plt.title("Number of Farms by Season")
plt.xlabel("Season")
plt.ylabel("Number of Farms")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **12. Seasonal Analysis**

# %% [markdown]
# ### Yield by Season

# %%
season_yield = (
    yield_df
    .groupby('Season', observed=True)['Yield_Tonnes_Ha']
    .agg(['count', 'mean', 'median', 'std', 'min', 'max'])
    .round(2)
)

season_yield
# Out:
#         count  mean  median    std  min     max
# Season
# Kharif   1772  5.64    1.95  14.42  0.3  101.44
# Rabi     1607  5.08    1.66  12.83  0.3   93.13
# Zaid      589  4.67    1.45  11.32  0.3   64.76

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=yield_df,
    x='Season',
    y='Yield_Tonnes_Ha',
    errorbar='ci'
)

plt.title("Average Agricultural Yield by Season")
plt.xlabel("Season")
plt.ylabel("Average Yield (Tonnes/Ha)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Yield Distributon by Season

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=yield_df,
    x='Season',
    y='Yield_Tonnes_Ha'
)

plt.title("Yield Distribution Across Seasons")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes/Ha)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Production by Seasons

# %%
production_by_season = (
    df.groupby('Season', observed=True)['Production_Tonnes']
    .agg(['mean', 'median', 'std', 'sum'])
    .round(2)
)

production_by_season
# Out:
#          mean  median    std       sum
# Season
# Kharif  46.31   13.24  135.7  82387.61
# Rabi    41.49   11.08  121.9  67498.88
# Zaid    38.89    9.97  112.0  23098.35

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x='Season',
    y='Production_Tonnes',
    errorbar='ci'
)

plt.title("Average Agricultural Production by Season")
plt.xlabel("Season")
plt.ylabel("Production (Tonnes)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Farm Area by Seasons

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Farm_Area_Hectares'
)

plt.title("Farm Area Distribution Across Seasons")
plt.xlabel("Season")
plt.ylabel("Farm Area (Hectares)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### RQ1: How does agricultural performance vary across seasons?
# #### Answer:
# Kharif
# * Average yield: 5.64 t/ha
# * Average production: 46.31 tonnes
# * Average profit: ₹178,914.65
# * Water efficiency: 5.89 t/1000 m³
# * Overall strongest performance.
#
# Rabi
#
# * Average yield: 5.08 t/ha
# * Average production: 41.49 tonnes
# * Average profit: ₹87,689.47
# * Water efficiency: 5.19 t/1000 m³
# * Moderate overall performance.
#
# Zaid
# * Average yield: 4.67 t/ha
# * Average production: 38.89 tonnes
# * Average profit: −₹24,804.82
# * Water efficiency: 4.41 t/1000 m³
# * Weakest overall performance.
#
# Interpretation
# * Agricultural performance clearly shows a general Kharif → Rabi → Zaid decline for the overall dataset.
# * Kharif provides the strongest overall agricultural and economic performance.
# * Zaid faces greater water requirements and lower efficiency.

# %% [markdown]
# ### Answer to RQ2: What major seasonal patterns can be observed?
#
# Based on the seasonal analysis of agricultural performance and environmental conditions, here are the major patterns observed:
#
#
# Yield: Kharif > Rabi > Zaid
#
# Production: Kharif > Rabi > Zaid
#
# Revenue: Kharif > Rabi > Zaid
#
# Profit: Kharif > Rabi > Zaid
#
# Rainfall: Kharif > Rabi > Zaid
#
# Humidity: Kharif > Rabi > Zaid
#
# Soil moisture: Kharif > Rabi >
# Zaid
#
# Temperature: Zaid > Kharif > Rabi
#
# Sunlight: Zaid > Rabi > Kharif
#
# Water usage: Zaid > Kharif > Rabi
#
# Water efficiency: Kharif > Rabi > Zaid
#
# Disease/pest risk: Kharif > Rabi > Zaid
#
# Main seasonal pattern
#
# * Kharif is wetter and more productive, while Zaid is hotter, drier, more water-dependent and less efficient.

# %% [markdown]
# ## **13. Environmental Analysis**

# %%
environmental_variables = [
    'Rainfall_mm',
    'Avg_Temperature_C',
    'Humidity_pct',
    'Sunlight_Hours_Day',
    'Soil_Moisture_pct'
]

season_environment = (
    df.groupby('Season', observed=True)[environmental_variables]
    .mean()
    .round(2)
)

season_environment
# Out:
#         Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# Season
# Kharif       849.20              28.45         71.81                6.79
# Rabi         437.62              23.49         57.89                7.59
# Zaid         304.65              31.04         52.01                8.18
#
#         Soil_Moisture_pct
# Season
# Kharif              31.15
# Rabi                24.07
# Zaid                19.28

# %% [markdown]
# ### Rainfall by Season

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Rainfall_mm'
)

plt.title("Rainfall Distribution Across Seasons")
plt.xlabel("Season")
plt.ylabel("Rainfall (mm)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Temperature By Season

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Avg_Temperature_C'
)

plt.title("Average Temperature Across Seasons")
plt.xlabel("Season")
plt.ylabel("Temperature (°C)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Humidity By Season

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Humidity_pct'
)

plt.title("Humidity Across Seasons")
plt.xlabel("Season")
plt.ylabel("Humidity (%)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sunlight by Season

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Sunlight_Hours_Day'
)

plt.title("Sunlight Duration Across Seasons")
plt.xlabel("Season")
plt.ylabel("Sunlight (Hours/Day)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Soil Conditions

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Soil_Moisture_pct'
)

plt.title("Soil Moisture Across Seasons")
plt.xlabel("Season")
plt.ylabel("Soil Moisture (%)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Answer to RQ3: Which characteristics change between seasons?
#
# Several environmental and agricultural characteristics change considerably.
#
# Environmental characteristics
#
# | Environmental characteristics | | | |
# | :--- | :--- | :--- | :--- |
# | **Characteristic** | **Kharif** | **Rabi** | **Zaid** |
# | Rainfall | 849.20 mm | 437.62 mm | 304.65 mm |
# | Temperature | 28.45°C | 23.49°C | 31.04°C |
# | Humidity | 71.81% | 57.89% | 52.01% |
# | Sunlight | 6.79 hrs | 7.59 hrs | 8.18 hrs |
# | Soil moisture | 31.15% | 24.07% | 19.28% |
#
# Interpretation
#
# * Kharif has high rainfall, humidity and soil moisture.
# * Rabi has the lowest temperature.
# * Zaid has high temperature and sunlight.
# * Zaid has the lowest soil moisture, indicating relatively drier conditions.

# %% [markdown]
# ### **RQ6. Are there relationships between seasonal environmental conditions and agricultural performance?**
#
# **Observed relationships**
#
# **Kharif:**
#
# High rainfall
#
# High humidity
#
# High soil moisture
#
# High yield
#
# High water efficiency
#
#
# **Zaid:**
#
# Low rainfall
#
# Low humidity
#
# Low soil moisture
#
# High temperature
#
# High sunlight
#
# Low yield
#
# Low water efficiency
#
# But correlation analysis shows:
#
# Rainfall vs Yield:
# approximately 0.031
#
# Temperature vs Yield: approximately 0.009
#
# Humidity vs Yield: approximately 0.011
#
# Soil moisture vs Yield: approximately 0.010
#
# Sunlight vs Yield: approximately −0.015
#
# Interpretation
#
# * Individual environmental variables have very weak overall linear correlations with yield.
# * Therefore, we cannot say that rainfall or temperature alone determines yield.
# * Agricultural performance is likely influenced by multiple factors together, such as:
#
#  crop type
#
#  region
#
#  irrigation
#
#  soil conditions
#
#  farming practices
#
#  resource usage
#
#  economic factors.

# %% [markdown]
# ## **14. Resource Analyis**

# %%
resource_variables = [
    'Nitrogen_kg_ha',
    'Phosphorus_kg_ha',
    'Potassium_kg_ha',
    'Fertilizer_kg_ha',
    'Pesticide_Litre_ha',
    'Water_Used_m3'
]

resource_by_season = (
    df.groupby('Season', observed=True)[resource_variables]
    .mean()
    .round(2)
)

resource_by_season
# Out:
#         Nitrogen_kg_ha  Phosphorus_kg_ha  Potassium_kg_ha  Fertilizer_kg_ha  \
# Season
# Kharif          120.02             58.10           105.30            187.08
# Rabi            120.40             57.31           103.93            185.41
# Zaid            120.53             58.13           105.42            184.64
#
#         Pesticide_Litre_ha  Water_Used_m3
# Season
# Kharif                5.08        6102.20
# Rabi                  5.02        5846.99
# Zaid                  5.17        6419.89

# %% [markdown]
# ### Fertilizer Usage

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Fertilizer_kg_ha'
)

plt.title("Fertilizer Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Fertilizer (kg/ha)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Water Usage

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Water_Used_m3'
)

plt.title("Water Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Water Used (m³)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Irrigation Method

# %%
irrigation_season = pd.crosstab(
    df['Season'],
    df['Irrigation_Method']
)

irrigation_season
# Out:
# Irrigation_Method  Drip  Flood  Rainfed  Sprinkler
# Season
# Kharif              405    590      463        321
# Rabi                370    526      438        293
# Zaid                140    194      140        120

# %%
irrigation_season.plot(
    kind='bar',
    figsize=(10, 6)
)

plt.title("Irrigation Methods Across Seasons")
plt.xlabel("Season")
plt.ylabel("Number of Farms")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Water Efficiency

# %%
water_efficiency = (
    df.groupby('Season', observed=True)
    ['Water_Efficiency_t_per_1000m3']
    .agg(['mean', 'median', 'std'])
    .round(2)
)

water_efficiency
# Out:
#         mean  median   std
# Season
# Kharif  5.89    3.28  9.83
# Rabi    5.19    2.74  8.26
# Zaid    4.41    2.30  6.93

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Water_Efficiency_t_per_1000m3'
)

plt.title("Water Efficiency Across Seasons")
plt.xlabel("Season")
plt.ylabel("Water Efficiency (Tonnes / 1000 m³)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Answer to RQ4: What differences exist between agricultural activities in different seasons?
#
# Crop performance
#
# Every crop showed the same general pattern:
#
# Kharif → highest yield
#
# Rabi → middle yield
#
# Zaid → lowest yield
#
# Examples:
#
# * Chilli: 1.73 → 1.46 → 1.18 t/ha
# * Cotton: 1.37 → 1.19 → 0.95 t/ha
# * Maize: 2.97 → 2.61 → 2.30 t/ha
# * Rice: 2.71 → 2.33 → 1.90 t/ha
# * Wheat: 2.26 → 2.06 → 1.75 t/ha
# * Sugarcane: 53.46 → 43.94 → 38.42 t/ha
#
# Interpretation
# * The seasonal effect is visible across all major crops in this dataset.
# * However, the magnitude of the difference varies by crop.
# * Sugarcane has a completely different production scale compared with the other crops.

# %% [markdown]
# ### **RQ5. Are there noticeable variations in resource usage across seasons?**
# Yes, particularly for water.
# | Resource | Kharif | Rabi | Zaid |
# | :--- | :--- | :--- | :--- |
# | **Nitrogen** | 120.02 | 120.40 | 120.53 |
# | **Phosphorus** | 58.10 | 57.31 | 58.13 |
# | **Potassium** | 105.30 | 103.93 | 105.42 |
# | **Fertilizer** | 187.08 | 185.41 | 184.64 |
# | **Pesticide** | 5.08 | 5.02 | 5.17 |
# | **Water Used** | 6102.20 | 5846.99 | 6419.89 |
#
# Interpretation
#
# Nitrogen, phosphorus, potassium, fertilizer and pesticide usage are quite similar across seasons.
#
# Water usage shows the most noticeable seasonal difference.
#
# Zaid uses the most water.
#
# Despite this, Zaid has the lowest water efficiency.
#
# Kharif has the highest water efficiency.
#
#
# Important finding
#
# Zaid appears to require greater water input without achieving corresponding water-use efficiency.

# %% [markdown]
# ## **15. Economic Analysis**

# %% [markdown]
# ### Creating Useful Derived Variables (Feature Engineering)

# %%
# Profit margin
df['Profit_Margin_pct'] = np.where(
    df['Revenue_INR'] != 0,
    (df['Profit_INR'] / df['Revenue_INR']) * 100,
    np.nan
)

# Cost per hectare
df['Cost_per_Hectare_INR'] = np.where(
    df['Farm_Area_Hectares'] != 0,
    df['Total_Cost_INR'] / df['Farm_Area_Hectares'],
    np.nan
)

# Revenue per hectare
df['Revenue_per_Hectare_INR'] = np.where(
    df['Farm_Area_Hectares'] != 0,
    df['Revenue_INR'] / df['Farm_Area_Hectares'],
    np.nan
)

# Profit per hectare
df['Profit_per_Hectare_INR'] = np.where(
    df['Farm_Area_Hectares'] != 0,
    df['Profit_INR'] / df['Farm_Area_Hectares'],
    np.nan
)

print("Derived variables created successfully.")
# Out:
# Derived variables created successfully.

# %%
df.shape
# Out:
# (4000, 32)

# %%
economic_variables = [
    'Market_Price_INR_Tonne',
    'Total_Cost_INR',
    'Revenue_INR',
    'Profit_INR',
    'Profit_Margin_pct'
]

economic_by_season = (
    df.groupby('Season', observed=True)[economic_variables]
    .mean()
    .round(2)
)

economic_by_season
# Out:
#         Market_Price_INR_Tonne  Total_Cost_INR  Revenue_INR  Profit_INR  \
# Season
# Kharif                44850.91       531804.41    710719.06   178914.65
# Rabi                  44747.97       513836.58    601526.05    87689.47
# Zaid                  44212.03       543976.73    519171.90   -24804.82
#
#         Profit_Margin_pct
# Season
# Kharif             -38.64
# Rabi               -44.27
# Zaid               -69.35

# %% [markdown]
# ### Profit By Season

# %%
economic_variables = [
    'Market_Price_INR_Tonne',
    'Total_Cost_INR',
    'Revenue_INR',
    'Profit_INR',
    'Profit_Margin_pct'
]

economic_by_season = (
    df.groupby('Season', observed=True)[economic_variables]
    .mean()
    .round(2)
)

economic_by_season
# Out:
#         Market_Price_INR_Tonne  Total_Cost_INR  Revenue_INR  Profit_INR  \
# Season
# Kharif                44850.91       531804.41    710719.06   178914.65
# Rabi                  44747.97       513836.58    601526.05    87689.47
# Zaid                  44212.03       543976.73    519171.90   -24804.82
#
#         Profit_Margin_pct
# Season
# Kharif             -38.64
# Rabi               -44.27
# Zaid               -69.35

# %% [markdown]
# ### Revenue by Season

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x='Season',
    y='Revenue_INR',
    errorbar='ci'
)

plt.title("Average Revenue by Season")
plt.xlabel("Season")
plt.ylabel("Average Revenue (INR)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cost Vs Revenue

# %%
economic_comparison = (
    df.groupby('Season', observed=True)
    [['Total_Cost_INR', 'Revenue_INR', 'Profit_INR']]
    .mean()
)

economic_comparison.plot(
    kind='bar',
    figsize=(10, 6)
)

plt.title("Average Cost, Revenue and Profit by Season")
plt.xlabel("Season")
plt.ylabel("Amount (INR)")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **RQ7. How do economic outcomes vary across seasons?**
#
# | Economic performance | | | |
# | :--- | :--- | :--- | :--- |
# | **Metric** | **Kharif** | **Rabi** | **Zaid** |
# | Revenue | ₹710,719 | ₹601,526 | ₹519,172 |
# | Cost | ₹531,804 | ₹513,837 | ₹543,977 |
# | Profit | ₹178,915 | ₹87,689 | -₹24,800 |
#
# Interpretation
#
# Kharif has the highest average revenue.
#
# Kharif also has the highest average profit.
#
# Rabi has lower revenue and profit but remains profitable on average.
#
# Zaid has the highest average cost but the lowest revenue.
#
# As a result, Zaid has a negative average profit.
#
#
# economic insight
#
# The most productive season is also the most profitable season, while Zaid faces both lower revenue and higher average cost.

# %% [markdown]
# ## **16. Crop x Season Analysis**

# %%
crop_season_yield = pd.pivot_table(
    yield_df,
    values='Yield_Tonnes_Ha',
    index='Crop',
    columns='Season',
    aggfunc='mean',
    observed=True
)

crop_season_yield.round(2)
# Out:
# Season     Kharif   Rabi   Zaid
# Crop
# Chilli       1.73   1.46   1.18
# Cotton       1.37   1.19   0.95
# Groundnut    1.48   1.22   1.04
# Maize        2.97   2.61   2.30
# Pulses       1.04   0.87   0.65
# Rice         2.71   2.33   1.90
# Sugarcane   53.46  43.94  38.42
# Wheat        2.26   2.06   1.75

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(
    crop_season_yield,
    annot=True,
    fmt='.2f',
    cmap='YlGnBu'
)

plt.title("Average Yield by Crop and Season")
plt.xlabel("Season")
plt.ylabel("Crop")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Crop production Analysis**

# %%
crop_production = pd.pivot_table(
    df,
    values='Production_Tonnes',
    index='Crop',
    columns='Season',
    aggfunc='mean',
    observed=True
)

crop_production.round(2)
# Out:
# Season     Kharif    Rabi    Zaid
# Crop
# Chilli      14.46   10.97    9.98
# Cotton      10.41    9.44    6.93
# Groundnut   10.49    9.06    8.62
# Maize       23.35   21.59   17.94
# Pulses       8.29    7.20    4.94
# Rice        22.45   17.22   15.11
# Sugarcane  446.07  365.26  329.56
# Wheat       18.31   16.07   14.06

# %% [markdown]
# ## **17. Region x Season Analysis**

# %%
state_season_yield = pd.pivot_table(
    yield_df,
    values='Yield_Tonnes_Ha',
    index='State',
    columns='Season',
    aggfunc='mean',
    observed=True
)

state_season_yield.round(2)
# Out:
# Season          Kharif  Rabi  Zaid
# State
# Andhra Pradesh    5.69  3.49  4.48
# Gujarat           6.34  5.52  4.10
# Karnataka         6.52  4.61  6.62
# Madhya Pradesh    6.00  3.80  5.54
# Maharashtra       5.45  5.50  2.29
# Punjab            4.10  8.61  5.91
# Tamil Nadu        5.52  4.56  4.10
# Telangana         5.57  4.83  4.28

# %%
plt.figure(figsize=(12, 7))

sns.heatmap(
    state_season_yield,
    annot=True,
    fmt='.2f',
    cmap='YlOrBr'
)

plt.title("Average Yield by State and Season")
plt.xlabel("Season")
plt.ylabel("State")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **RQ8 Are some seasonal patterns consistent across different regions or categories?**
#
#
# Yes, but not completely.
#
# Most crops:
#
# Kharif = highest yield
# Rabi = middle
# Zaid = lowest
#
# However, regional results show exceptions.
#
# State-level examples
#
# Punjab
#
# Kharif: 4.10
# Rabi: 8.61
# Zaid: 5.91
#
# → Punjab performs exceptionally well in Rabi.
#
# Karnataka
#
# Kharif: 6.52
# Rabi: 4.61
# Zaid: 6.62
#
# → Zaid slightly outperforms Kharif.
#
# Maharashtra
#
# Kharif: 5.45
# Rabi: 5.50
# Zaid: 2.29
#
# → Kharif and Rabi are almost identical.
#
# Interpretation
#
# Seasonal patterns are generally consistent, especially across crops.
# But they are not universal across regions.
# Regional agricultural conditions can change the seasonal pattern.
# Therefore, agricultural planning should not use one strategy for every state.

# %% [markdown]
# ## **Irrigation Method vs Yield**

# %%
irrigation_yield = (
    yield_df
    .groupby('Irrigation_Method', observed=True)
    ['Yield_Tonnes_Ha']
    .agg(['count', 'mean', 'median', 'std'])
    .round(2)
)

irrigation_yield
# Out:
#                    count  mean  median    std
# Irrigation_Method
# Drip                 907  6.62    1.96  16.26
# Flood               1296  4.90    1.63  12.65
# Rainfed             1037  4.61    1.72  11.58
# Sprinkler            728  5.19    1.80  12.86

# %%
plt.figure(figsize=(9, 5))

sns.boxplot(
    data=yield_df,
    x='Irrigation_Method',
    y='Yield_Tonnes_Ha'
)

plt.title("Yield Distribution by Irrigation Method")
plt.xlabel("Irrigation Method")
plt.ylabel("Yield (Tonnes/Ha)")
plt.xticks(rotation=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **18. Disease/Pest Risk by Season**

# %%
risk_by_season = (
    df.groupby('Season', observed=True)
    ['Disease_Pest_Risk_pct']
    .agg(['mean', 'median', 'std'])
    .round(2)
)

risk_by_season
# Out:
#          mean  median    std
# Season
# Kharif  54.47    54.5  10.09
# Rabi    40.48    40.6  10.10
# Zaid    38.22    37.9   9.87

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x='Season',
    y='Disease_Pest_Risk_pct'
)

plt.title("Disease and Pest Risk Across Seasons")
plt.xlabel("Season")
plt.ylabel("Disease/Pest Risk (%)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Disease Risk vs Yield**

# %%
plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=yield_df,
    x='Disease_Pest_Risk_pct',
    y='Yield_Tonnes_Ha',
    hue='Season',
    alpha=0.6
)

plt.title("Disease/Pest Risk vs Agricultural Yield")
plt.xlabel("Disease/Pest Risk (%)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **19. Environmental Relationships**

# %% [markdown]
# ### Rainfall vs Yield

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=yield_df,
    x='Rainfall_mm',
    y='Yield_Tonnes_Ha',
    hue='Season',
    alpha=0.6
)

plt.title("Rainfall vs Agricultural Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Temperature vs Yield

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=yield_df,
    x='Avg_Temperature_C',
    y='Yield_Tonnes_Ha',
    hue='Season',
    alpha=0.6
)

plt.title("Temperature vs Agricultural Yield")
plt.xlabel("Average Temperature (°C)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Soil Moisture vs Yield

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=yield_df,
    x='Soil_Moisture_pct',
    y='Yield_Tonnes_Ha',
    hue='Season',
    alpha=0.6
)

plt.title("Soil Moisture vs Agricultural Yield")
plt.xlabel("Soil Moisture (%)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **20. Correlation Analysis**

# %%
correlation_variables = [
    'Rainfall_mm',
    'Avg_Temperature_C',
    'Humidity_pct',
    'Sunlight_Hours_Day',
    'Soil_pH',
    'Soil_Moisture_pct',
    'Nitrogen_kg_ha',
    'Phosphorus_kg_ha',
    'Potassium_kg_ha',
    'Fertilizer_kg_ha',
    'Pesticide_Litre_ha',
    'Seed_Quality_Score',
    'Yield_Tonnes_Ha',
    'Production_Tonnes',
    'Water_Used_m3',
    'Water_Efficiency_t_per_1000m3',
    'Disease_Pest_Risk_pct'
]

correlation_matrix = yield_df[correlation_variables].corr()

correlation_matrix.round(2)
# Out:
#                                Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Rainfall_mm                           1.00               0.20          0.52
# Avg_Temperature_C                     0.20               1.00          0.14
# Humidity_pct                          0.52               0.14          1.00
# Sunlight_Hours_Day                   -0.36              -0.03         -0.30
# Soil_pH                               0.02               0.03          0.03
# Soil_Moisture_pct                     0.51               0.08          0.45
# Nitrogen_kg_ha                        0.01               0.02          0.00
# Phosphorus_kg_ha                      0.02               0.01         -0.01
# Potassium_kg_ha                       0.03               0.02         -0.00
# Fertilizer_kg_ha                      0.03               0.01          0.03
# Pesticide_Litre_ha                    0.00               0.01         -0.00
# ...

# %%
# Correlation Heatmap
plt.figure(figsize=(15, 11))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0
)

plt.title("Correlation Matrix of Agricultural Variables")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation with yield

# %%
yield_correlations = (
    correlation_matrix['Yield_Tonnes_Ha']
    .drop('Yield_Tonnes_Ha')
    .sort_values(ascending=False)
)

yield_correlations.round(3)
# Out:
# Water_Efficiency_t_per_1000m3    0.915
# Production_Tonnes                0.885
# Water_Used_m3                    0.389
# Nitrogen_kg_ha                   0.054
# Phosphorus_kg_ha                 0.048
# Rainfall_mm                      0.031
# Disease_Pest_Risk_pct            0.013
# Humidity_pct                     0.011
# Soil_Moisture_pct                0.010
# Avg_Temperature_C                0.009
# Potassium_kg_ha                  0.004
# Fertilizer_kg_ha                 0.001
# Seed_Quality_Score              -0.007
# Pesticide_Litre_ha              -0.008
# Sunlight_Hours_Day              -0.015
# Soil_pH                         -0.021
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Top Positive and Negative Relationships
print("Top Positive Correlations with Yield:")
print(yield_correlations.head(5))

print("\nTop Negative Correlations with Yield:")
print(yield_correlations.tail(5))
# Out:
# Top Positive Correlations with Yield:
# Water_Efficiency_t_per_1000m3    0.915438
# Production_Tonnes                0.885171
# Water_Used_m3                    0.388653
# Nitrogen_kg_ha                   0.053867
# Phosphorus_kg_ha                 0.047821
# Name: Yield_Tonnes_Ha, dtype: float64
#
# Top Negative Correlations with Yield:
# Fertilizer_kg_ha      0.000562
# Seed_Quality_Score   -0.006737
# Pesticide_Litre_ha   -0.007650
# Sunlight_Hours_Day   -0.015362
# Soil_pH              -0.020664
# Name: Yield_Tonnes_Ha, dtype: float64

# %% [markdown]
# ### **RQ6. Are there relationships between seasonal environmental conditions and agricultural performance?**
#
# **Observed relationships**
#
# **Kharif:**
#
# High rainfall
#
# High humidity
#
# High soil moisture
#
# High yield
#
# High water efficiency
#
#
# **Zaid:**
#
# Low rainfall
#
# Low humidity
#
# Low soil moisture
#
# High temperature
#
# High sunlight
#
# Low yield
#
# Low water efficiency
#
# But correlation analysis shows:
#
# Rainfall vs Yield:
# approximately 0.031
#
# Temperature vs Yield: approximately 0.009
#
# Humidity vs Yield: approximately 0.011
#
# Soil moisture vs Yield: approximately 0.010
#
# Sunlight vs Yield: approximately −0.015
#
# Interpretation
#
# * Individual environmental variables have very weak overall linear correlations with yield.
# * Therefore, we cannot say that rainfall or temperature alone determines yield.
# * Agricultural performance is likely influenced by multiple factors together, such as:
#
#  crop type
#
#  region
#
#  irrigation
#
#  soil conditions
#
#  farming practices
#
#  resource usage
#
#  economic factors.

# %% [markdown]
# ## **21. Statistical Test**
#
# Hypothesis
#
# H0: Mean yield is equal across all seasons.
#
# H1: At least one season has a different mean yield.

# %%
# ONE-WAY ANOVA: YIELD ACROSS SEASONS
kharif_yield = yield_df[
    yield_df['Season'] == 'Kharif'
]['Yield_Tonnes_Ha']

rabi_yield = yield_df[
    yield_df['Season'] == 'Rabi'
]['Yield_Tonnes_Ha']

zaid_yield = yield_df[
    yield_df['Season'] == 'Zaid'
]['Yield_Tonnes_Ha']

anova_result = stats.f_oneway(
    kharif_yield,
    rabi_yield,
    zaid_yield
)

print("ANOVA F-statistic:", anova_result.statistic)
print("ANOVA p-value:", anova_result.pvalue)
# Out:
# ANOVA F-statistic: 1.4579589466621523
# ANOVA p-value: 0.23283549440109827

# %%
# Interpret ANOVA

alpha = 0.05

if anova_result.pvalue < alpha:
    print(
        "Result: Reject the null hypothesis."
    )
    print(
        "There is statistically significant evidence that "
        "mean yield differs across seasons."
    )
else:
    print(
        "Result: Fail to reject the null hypothesis."
    )
    print(
        "There is insufficient statistical evidence that "
        "mean yield differs across seasons."
    )
# Out:
# Result: Fail to reject the null hypothesis.
# There is insufficient statistical evidence that mean yield differs across seasons.

# %% [markdown]
# ### **Kruskal-Wallis Test**

# %%
kruskal_result = stats.kruskal(
    kharif_yield,
    rabi_yield,
    zaid_yield
)

print("Kruskal-Wallis statistic:", kruskal_result.statistic)
print("Kruskal-Wallis p-value:", kruskal_result.pvalue)
# Out:
# Kruskal-Wallis statistic: 68.60429543046561
# Kruskal-Wallis p-value: 1.2669705784969668e-15

# %%
#  Interpretation
if kruskal_result.pvalue < 0.05:
    print(
        "There is statistically significant evidence "
        "of differences in yield distributions across seasons."
    )
else:
    print(
        "There is insufficient statistical evidence "
        "of differences in yield distributions across seasons."
    )
# Out:
# There is statistically significant evidence of differences in yield distributions across seasons.

# %% [markdown]
# ### **Seasonal Economic Statistical Test**

# %%
kharif_profit = df[
    df['Season'] == 'Kharif'
]['Profit_INR'].dropna()

rabi_profit = df[
    df['Season'] == 'Rabi'
]['Profit_INR'].dropna()

zaid_profit = df[
    df['Season'] == 'Zaid'
]['Profit_INR'].dropna()

profit_anova = stats.f_oneway(
    kharif_profit,
    rabi_profit,
    zaid_profit
)

print("Profit ANOVA F-statistic:", profit_anova.statistic)
print("Profit ANOVA p-value:", profit_anova.pvalue)
# Out:
# Profit ANOVA F-statistic: 34.29175033935195
# Profit ANOVA p-value: 1.7124156677360182e-15

# %% [markdown]
# ## **Seasonal Summary Table**

# %%
# ============================================================
# FINAL SEASONAL PERFORMANCE SUMMARY
# ============================================================

season_summary = df.groupby(
    'Season',
    observed=True
).agg(
    Farms=('Farm_ID', 'count'),
    Average_Yield=('Yield_Tonnes_Ha', 'mean'),
    Average_Production=('Production_Tonnes', 'mean'),
    Average_Rainfall=('Rainfall_mm', 'mean'),
    Average_Temperature=('Avg_Temperature_C', 'mean'),
    Average_Water_Used=('Water_Used_m3', 'mean'),
    Average_Water_Efficiency=(
        'Water_Efficiency_t_per_1000m3',
        'mean'
    ),
    Average_Revenue=('Revenue_INR', 'mean'),
    Average_Cost=('Total_Cost_INR', 'mean'),
    Average_Profit=('Profit_INR', 'mean'),
    Average_Disease_Risk=('Disease_Pest_Risk_pct', 'mean')
).round(2)

season_summary
# Out:
#         Farms  Average_Yield  Average_Production  Average_Rainfall  \
# Season
# Kharif   1779           5.64               46.31            849.20
# Rabi     1627           5.08               41.49            437.62
# Zaid      594           4.67               38.89            304.65
#
#         Average_Temperature  Average_Water_Used  Average_Water_Efficiency  \
# Season
# Kharif                28.45             6102.20                      5.89
# Rabi                  23.49             5846.99                      5.19
# Zaid                  31.04             6419.89                      4.41
#
#         Average_Revenue  Average_Cost  Average_Profit  Average_Disease_Risk
# Season
# Kharif        710719.06     531804.41       178914.65                 54.47
# Rabi          601526.05     513836.58        87689.47                 40.48
# Zaid          519171.90     543976.73       -24804.82                 38.22

# %% [markdown]
# ### Identifying Best and Worst Season

# %%
# Best and worst seasons based on average yield

best_yield_season = (
    season_summary['Average_Yield'].idxmax()
)

worst_yield_season = (
    season_summary['Average_Yield'].idxmin()
)

print("Highest average yield:", best_yield_season)
print("Lowest average yield:", worst_yield_season)
# Out:
# Highest average yield: Kharif
# Lowest average yield: Zaid

# %%
# For Profit
best_profit_season = (
    season_summary['Average_Profit'].idxmax()
)

worst_profit_season = (
    season_summary['Average_Profit'].idxmin()
)

print("Highest average profit:", best_profit_season)
print("Lowest average profit:", worst_profit_season)
# Out:
# Highest average profit: Kharif
# Lowest average profit: Zaid

# %%
# Water Efficiency
best_water_efficiency_season = (
    season_summary['Average_Water_Efficiency'].idxmax()
)

print(
    "Highest water efficiency:",
    best_water_efficiency_season
)
# Out:
# Highest water efficiency: Kharif

# %% [markdown]
# ## Identify Highest/Lowest Values Automatically

# %%
# AUTOMATICALLY GENERATE KEY SEASONAL OBSERVATIONS
metrics = [
    'Average_Yield',
    'Average_Production',
    'Average_Rainfall',
    'Average_Temperature',
    'Average_Water_Used',
    'Average_Water_Efficiency',
    'Average_Revenue',
    'Average_Cost',
    'Average_Profit',
    'Average_Disease_Risk'
]

for metric in metrics:
    highest = season_summary[metric].idxmax()
    lowest = season_summary[metric].idxmin()

    print(f"\n{metric}")
    print(f"Highest: {highest}")
    print(f"Lowest : {lowest}")
# Out:
# Average_Yield
# Highest: Kharif
# Lowest : Zaid
#
# Average_Production
# Highest: Kharif
# Lowest : Zaid
#
# Average_Rainfall
# Highest: Kharif
# Lowest : Zaid
#
# Average_Temperature
# Highest: Zaid
# Lowest : Rabi
#
# Average_Water_Used
# Highest: Zaid
# Lowest : Rabi
#
# Average_Water_Efficiency
# Highest: Kharif
# Lowest : Zaid
#
# Average_Revenue
# Highest: Kharif
# Lowest : Zaid
#
# Average_Cost
# Highest: Zaid
# Lowest : Rabi
#
# Average_Profit
# Highest: Kharif
# Lowest : Zaid
#
# Average_Disease_Risk
# Highest: Kharif
# Lowest : Zaid

# %% [markdown]
# ## Top Performing Crops

# %%
crop_performance = (
    yield_df.groupby('Crop', observed=True)
    .agg(
        Average_Yield=('Yield_Tonnes_Ha', 'mean'),
        Average_Production=('Production_Tonnes', 'mean'),
        Average_Profit=('Profit_INR', 'mean')
    )
    .sort_values(
        'Average_Yield',
        ascending=False
    )
    .round(2)
)

crop_performance
# Out:
#            Average_Yield  Average_Production  Average_Profit
# Crop
# Sugarcane          46.94              392.36       817245.40
# Maize               2.72               21.72       -82749.43
# Rice                2.44               19.32      -101405.00
# Wheat               2.11               16.89      -123567.97
# Chilli              1.54               12.40       753377.50
# Groundnut           1.32                9.66        44604.38
# Cotton              1.23                9.42       124969.85
# Pulses              0.92                7.42        -3987.21

# %% [markdown]
# ## Best Crop Season Combination

# %%
crop_season_performance = (
    yield_df.groupby(
        ['Crop', 'Season'],
        observed=True
    )
    .agg(
        Average_Yield=('Yield_Tonnes_Ha', 'mean'),
        Average_Profit=('Profit_INR', 'mean')
    )
    .reset_index()
    .sort_values(
        'Average_Yield',
        ascending=False
    )
)

crop_season_performance.head(10)
# Out:
#          Crop  Season  Average_Yield  Average_Profit
# 18  Sugarcane  Kharif      53.459120    1.000791e+06
# 19  Sugarcane    Rabi      43.940394    7.304022e+05
# 20  Sugarcane    Zaid      38.423922    5.836358e+05
# 9       Maize  Kharif       2.966410   -3.933267e+04
# 15       Rice  Kharif       2.707621   -6.552983e+04
# 10      Maize    Rabi       2.614913   -8.783088e+04
# 16       Rice    Rabi       2.333680   -9.516737e+04
# 11      Maize    Zaid       2.297590   -1.910722e+05
# 21      Wheat  Kharif       2.255430   -1.060058e+05
# 22      Wheat    Rabi       2.058814   -1.201405e+05

# %% [markdown]
# ## Best State-Season Combination

# %%
state_season_performance = (
    yield_df.groupby(
        ['State', 'Season'],
        observed=True
    )
    .agg(
        Average_Yield=('Yield_Tonnes_Ha', 'mean'),
        Average_Profit=('Profit_INR', 'mean')
    )
    .reset_index()
    .sort_values(
        'Average_Yield',
        ascending=False
    )
)

state_season_performance.head(15)
# Out:
#              State  Season  Average_Yield  Average_Profit
# 16          Punjab    Rabi       8.609355   169294.521505
# 8        Karnataka    Zaid       6.623243    23310.905405
# 6        Karnataka  Kharif       6.523689   202571.398058
# 3          Gujarat  Kharif       6.338416   217051.330317
# 9   Madhya Pradesh  Kharif       6.004133   134187.493333
# 17          Punjab    Zaid       5.909610    62109.688312
# 0   Andhra Pradesh  Kharif       5.693431   169961.924686
# 21       Telangana  Kharif       5.568798   200398.635193
# 11  Madhya Pradesh    Zaid       5.539194     2539.629032
# 18      Tamil Nadu  Kharif       5.520534   211303.956311
# 4          Gujarat    Rabi       5.517245    85405.183673
# 13     Maharashtra    Rabi       5.501927   159581.504587
# 12     Maharashtra  Kharif       5.447014   169867.552036
# 22       Telangana    Rabi       4.831649    62451.891753
# 7        Karnataka    Rabi       4.609655    67875.108374

# %% [markdown]
# ## Seasonal Variability

# %%
season_variability = (
    yield_df.groupby('Season', observed=True)
    ['Yield_Tonnes_Ha']
    .agg(['mean', 'std'])
)

season_variability['CV_percent'] = (
    season_variability['std'] /
    season_variability['mean']
) * 100

season_variability.round(2)
# Out:
#         mean    std  CV_percent
# Season
# Kharif  5.64  14.42      255.48
# Rabi    5.08  12.83      252.44
# Zaid    4.67  11.32      242.56

# %% [markdown]
# ## Final Correlation with Economic Performance

# %%
economic_correlation_variables = [
    'Yield_Tonnes_Ha',
    'Production_Tonnes',
    'Market_Price_INR_Tonne',
    'Total_Cost_INR',
    'Revenue_INR',
    'Profit_INR',
    'Water_Efficiency_t_per_1000m3'
]

economic_corr = (
    yield_df[economic_correlation_variables]
    .corr()
)

plt.figure(figsize=(10, 7))

sns.heatmap(
    economic_corr,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0
)

plt.title("Correlation Between Agricultural Performance and Economic Variables")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### RQ10 What insights can be derived from the observed seasonal differences?
#
# Main insights
#
# Season has a strong practical association with agricultural performance.
# Kharif appears to provide the most favorable overall conditions.
# Zaid requires greater attention to water management.
# Crop selection should consider both season and region.
# Disease/pest management is especially important during Kharif.
# Water efficiency should be monitored rather than simply measuring total water used.
# Drip irrigation is associated with higher average yield than other irrigation methods.
# Profitability should be evaluated along with yield.
# Some crops may generate better economic returns despite lower physical yield.
# Regional strategies are necessary because seasonal performance differs between states.

# %% [markdown]
# ### RQ11. What conclusions can reasonably be drawn from the available data?
#
# Conclusions
#
# Kharif has the best overall agricultural performance in this dataset.
#
# Zaid has the weakest overall performance.
#
# Rabi has intermediate performance but can be highly successful in particular regions.
#
# Seasonal differences are visible in:
#
# -environmental conditions
#
# -yield
#
# -production
#
# -water use
#
# -water efficiency
#
# -disease/pest risk
#
# -revenue
#
# -profit.
#
# Resource usage for fertilizers and nutrients is relatively stable across seasons.
#
# Water usage varies more strongly across seasons.
#
# Zaid has a particularly important water-efficiency problem.
#
# Seasonal patterns differ across states, so regional planning is important.
#
# The data shows associations and patterns, but does not prove causation.
#
# The correlation analysis suggests that no single environmental variable explains yield.
#
# Statistical testing indicates that yield distributions differ across seasons, while the ANOVA result does not establish a significant difference in mean yield.

# %% [markdown]
# ## Final Research Questions Summary
#
#
# | Research Question | Final Answer |
# | :--- | :--- |
# | How does agricultural performance vary across seasons? | Kharif shows the strongest overall performance, followed by Rabi and Zaid. |
# | What major seasonal patterns can be observed? | Kharif generally has higher yield, production, revenue and water efficiency, while Zaid shows weaker performance. |
# | Which characteristics change between seasons? | Rainfall, temperature, humidity, sunlight and soil moisture show clear seasonal differences. |
# | What differences exist between agricultural activities? | Crop performance and irrigation practices vary across seasons, with crop-specific and regional differences. |
# | Are there variations in resource usage? | Water usage varies noticeably, while nutrient and fertilizer usage remains relatively similar. |
# | Are environmental conditions related to performance? | Seasonal environmental conditions differ strongly, but individual environmental variables have weak linear correlations with yield. |
# | How do economic outcomes vary? | Kharif has the highest average profit, while Zaid has negative average profit. |
# | Are patterns consistent across regions/categories? | Patterns are mostly consistent across crops but vary considerably across states. |
# | Are there unusual patterns? | Punjab Rabi and Karnataka Zaid are notable exceptions, and Sugarcane produces extreme values. |
# | What insights can be derived? | Season, crop, region, water use and profitability should be considered together. |
# | What conclusions can be drawn? | Seasonal differences are important, but they should not be interpreted as direct causal effects. |
# | How can findings support planning? | Use season-, crop-, region- and resource-specific agricultural planning. |

# %% [markdown]
# ## **22. Key Findings**
#
# Based on the analysis performed on the agricultural dataset, the following
# major findings were identified:
#
# -Kharif showed the strongest overall agricultural performance, with the highest average yield, production, revenue, profit and water efficiency.
#
# -Zaid showed the weakest performance, with the lowest yield, production, revenue and profit.
#
# -Zaid also had the highest water usage and lowest water efficiency, indicating a need for better water management.
#
# -Kharif had the highest disease/pest risk, requiring stronger monitoring and preventive measures.
#
# -Drip irrigation showed the highest average yield among irrigation methods.
#
# -All analyzed crops recorded their highest average yield in Kharif and lowest in Zaid.
#
# -Seasonal patterns were not completely uniform across regions, with Punjab performing exceptionally well in Rabi and Karnataka showing strong Zaid performance.
#
# -Environmental variables showed strong differences between seasons, but their individual linear correlations with yield were weak.
#
# -Profitability varied significantly across seasons, and high yield did not always translate into high profit.
#
# -Statistical analysis suggests significant differences in yield distributions across seasons, while mean-yield differences should be interpreted cautiously because of the skewed dataset and crop-scale differences.
#
# -Overall, the analysis supports season-, crop-, region- and resource-specific agricultural planning.

# %% [markdown]
# ## **23. Recommendations**
#
# Based on the findings of the analysis, the following recommendations can be
# considered:
#
# 1. Seasonal agricultural planning should consider differences in yield,
#    environmental conditions and resource requirements.
#
# 2. Farmers and agricultural planners should consider crop-specific seasonal
#    performance rather than assuming that one season is optimal for every crop.
#
# 3. Water management strategies should consider the observed differences in
#    water usage and water-use efficiency across seasons.
#
# 4. Regions showing relatively lower seasonal performance may require further
#    investigation of environmental conditions, irrigation practices and
#    resource availability.
#
# 5. Seasonal disease and pest risk patterns should be monitored to support
#    timely agricultural risk-management decisions.
#
# 6. Resource allocation can be informed by observed seasonal differences in
#    fertilizer, pesticide and water usage.
#
# 7. Economic planning should consider both production and profitability,
#    since higher production does not necessarily imply higher profit.
#
# 8. Environmental variables that show meaningful associations with yield
#    should be considered during seasonal agricultural planning.
#
# 9. Unusual observations should be investigated individually before making
#    operational decisions.
#
# 10. Future studies could incorporate additional factors such as historical
#     weather data, market trends, soil characteristics and long-term
#     agricultural records.

# %% [markdown]
# ## **24. Conclusion**
#
# The analysis shows that agricultural performance varies considerably across seasons.
#
# Kharif emerged as the strongest overall season, supported by higher rainfall, humidity and soil moisture, along with higher yield, production, revenue, profit and water efficiency.
#
# Zaid showed comparatively weaker performance, characterized by higher temperature, lower rainfall and soil moisture, greater water consumption and lower water-use efficiency.
#
# Rabi showed moderate overall performance but demonstrated strong results in certain regions such as Punjab.
#
# The analysis also showed that seasonal patterns are not identical across all crops and regions.
#
# Crop type plays an important role, with Sugarcane showing exceptionally high production and yield compared with other crops.
#
# Economic analysis demonstrated that agricultural success cannot be evaluated using yield alone, because market prices and production costs can cause high-yield crops to be unprofitable.
#
# Correlation analysis showed that individual environmental factors had weak linear relationships with yield, suggesting that agricultural performance is influenced by multiple interacting factors rather than one environmental variable.
#
# Statistical testing provided evidence of differences in yield distributions across seasons, while the ANOVA result indicated that mean-yield differences should be interpreted cautiously.
#
# Overall, the findings support data-driven seasonal agricultural planning, where crop selection, irrigation, resource allocation, disease management, regional conditions and profitability are considered together.

# %% [markdown]
# ## **Interpretation**
#
# The boxplot compares the distribution of agricultural yield across Kharif,
# Rabi and Zaid seasons. The median, spread and range of yield are different
# across the three seasons. The seasonal averages should be considered along
# with the variability shown in the boxplot rather than relying only on a
# single average value.
#
# The statistical tests performed later in the analysis are used to determine
# whether the observed seasonal differences are statistically significant.
